# %%
import pandas as pd
base_unificada = r'C:\Users\nicof\Documents\Seguimiento1_Metodos_de_Ordenamiento\bases_unificadas_ok.csv'

df = pd.read_csv(base_unificada)

print(df.head())
# Out:
#                                               Título  \
# 0  STEAM, PROJETOS E O PENSAMENTO COMPUTACIONAL N...
# 1  The SNS-based E-mentoring and Development of C...
# 2  Effects of a teacher development program on te...
# 3  Classroom Play and Activities to Support Compu...
# 4  How a Rubric Score Application Empowers Teache...
#
#                                              Autores  \
# 0  de Almeida Rosa, Thais; de Lima Terçariol, Adr...
# 1  Yeonju Jang; Seongyune Choi; Seonghun Kim; Hye...
# 2                        Kong, Siu‐Cheung; Lai, Ming
# 3        Lee, Joohi; Joswick, Candace; Pole, Kathryn
# 4  Dimos, Ioannis; Velaora, Chrysoula; Louvaris, ...
#
#                                      Revista         ISSN Fecha Publicacion  \
# 0                 Eccos - Revista Científica  ="15171949"    ="abr-jun2023"
# 1           Educational Technology & Society  ="11763647"        ="Apr2023"
# 2  British Journal of Educational Technology  ="00071013"        ="Mar2023"
# 3          Early Childhood Education Journal  ="10823301"        ="Mar2023"
# 4                    Information (2078-2489)  ="20782489"        ="Feb2023"
#
#                               DOI  \
# 0         10.5585/eccos.n65.24626
# 1  10.30191/ETS.202304_26(2).0011
# 2              10.1111/bjet.13256
# 3      10.1007/s10643-022-01319-0
# 4            10.3390/info14020118
#
#                                       Palabras Clave Volumen Asunto  \
# 0  basic education; computational thinking; eleme...     NaN     65
# 1  Computational thinking; Computational thinking...    26.0      2
# 2  collaborative engagement; computational thinki...    54.0      2
# 3  Algorithm; Computational thinking (CT); CT pra...    51.0      3
# 4  application; computational thinking; descripti...    14.0      2
#
#   Primera Pagina  Paginas                                          Publisher  \
# 0              1     21.0                         Eccos - Revista Cientifica
# 1            147     18.0  International Forum of Educational Technology ...
# 2            489     24.0                                    Wiley-Blackwell
# 3            457     12.0                                    Springer Nature
# 4            118     20.0                                               MDPI
#
#       Tipo                                           Abstract  \
# 0  Article  This article is an excerpt from a dissertation...
# 1  Article  Given the importance of digital technology in ...
# 2  Article  An important educational goal for the next gen...
# 3  Article  This is a conceptual paper based on existing l...
# 4  Article  Computational Thinking (CT) has emerged as an ...
#
#                                                 Link
# 0  https://crai.referencistas.com/login?url=https...
# 1  https://crai.referencistas.com/login?url=https...
# 2  https://crai.referencistas.com/login?url=https...
# 3  https://crai.referencistas.com/login?url=https...
# 4  https://crai.referencistas.com/login?url=https...

# %%
import time

# %% [markdown]
# ISSn

# %%
# Función para construir el Heap
def heapify(arr, n, i):
    largest = i  # Inicializar el nodo más grande como la raíz
    left = 2 * i + 1  # Izquierda = 2*i + 1
    right = 2 * i + 2  # Derecha = 2*i + 2

    # Si el hijo izquierdo es mayor que la raíz
    if left < n and arr[left] > arr[largest]:
        largest = left

    # Si el hijo derecho es mayor que el mayor hasta ahora
    if right < n and arr[right] > arr[largest]:
        largest = right

    # Si el mayor no es la raíz
    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i]  # Intercambiar
        heapify(arr, n, largest)  # Recursivamente heapificar el subárbol afectado

# Función para implementar Heap Sort
def heap_sort(arr):
    n = len(arr)

    # Construir el heap (reordenar la matriz)
    for i in range(n // 2 - 1, -1, -1):
        heapify(arr, n, i)

    # Extraer elementos del heap uno por uno
    for i in range(n - 1, 0, -1):
        arr[i], arr[0] = arr[0], arr[i]  # Intercambiar el primer elemento con el último
        heapify(arr, i, 0)  # Heapificar el árbol reducido

# Obtener los ISSN válidos
def obtener_issn_validos(df, column_name='ISSN'):
    # Asegurarse de que la columna exista y eliminar espacios
    df[column_name] = df[column_name].str.strip()
    # Eliminar valores nulos
    return df[column_name].dropna().tolist()

# Preparar la lista de ISSN
issn_validos = obtener_issn_validos(df)

# Variables para medir tiempo de ejecución
tiempos = []
num_ejecuciones = 4

# Realizar 4 ejecuciones y medir el tiempo
for i in range(num_ejecuciones):
    start_time = time.time()  # Inicio del temporizador
    # Ordenar los ISSN utilizando Heap Sort
    heap_sort(issn_validos.copy())  # Usar copy() para evitar modificar la lista original
    end_time = time.time()  # Fin del temporizador
    tiempos.append(end_time - start_time)  # Guardar el tiempo de ejecución

# Mostrar resultados
print(f"Total de ISSN válidos: {len(issn_validos)}")
print(f"Tiempos de ejecución en {num_ejecuciones} ejecuciones: {tiempos}")
# Out:
# Total de ISSN válidos: 5607
# Tiempos de ejecución en 4 ejecuciones: [0.021040678024291992, 0.019927024841308594, 0.021712303161621094, 0.019643783569335938]

# %% [markdown]
# Fecha

# %%
import re
# Función para hacer heapify
def heapify(arr, n, i):
    largest = i  # Inicializar el nodo más grande como raíz
    l = 2 * i + 1  # Índice del hijo izquierdo
    r = 2 * i + 2  # Índice del hijo derecho

    # Si el hijo izquierdo es mayor que la raíz
    if l < n and arr[l] > arr[largest]:
        largest = l

    # Si el hijo derecho es mayor que el más grande hasta ahora
    if r < n and arr[r] > arr[largest]:
        largest = r

    # Si el más grande no es la raíz
    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i]  # Intercambiar

        # Recursivamente hacer heapify en el subárbol afectado
        heapify(arr, n, largest)

# Función principal para hacer heap sort
def heapSort(arr):
    n = len(arr)

    # Construir el heap (reorganizar el array)
    for i in range(n // 2 - 1, -1, -1):
        heapify(arr, n, i)

    # Extraer elementos uno por uno del heap
    for i in range(n - 1, 0, -1):
        # Mover la raíz actual al final
        arr[0], arr[i] = arr[i], arr[0]
        # Llamar a heapify en el heap reducido
        heapify(arr, i, 0)

# Función para extraer el año de 'Fecha Publicacion'
def extraer_anio(fecha):
    match = re.search(r'\d{4}', fecha)
    if match:
        return int(match.group(0))
    return None

# Preparar los datos de la columna 'Fecha Publicacion'
def preparar_datos_fecha_publicacion(df, column_name='Fecha Publicacion'):
    df[column_name] = df[column_name].apply(lambda x: extraer_anio(str(x)))

    total_caracteres = df[column_name].astype(str).str.len().sum()
    total_elementos = df[column_name].count()

    print(f"Total de caracteres en la columna '{column_name}': {total_caracteres}")
    print(f"Total de elementos en la columna '{column_name}': {total_elementos}")

    return df

# Adaptar HeapSort para ordenar la columna 'Fecha Publicacion'
def ordenar_heap_fecha_publicacion(df, column_name='Fecha Publicacion'):
    fecha_list = df[column_name].dropna().tolist()
    heapSort(fecha_list)
    df[column_name] = pd.Series(fecha_list + [None] * (len(df) - len(fecha_list)), index=df.index)
    return df

# Preparar los datos de la columna 'Fecha Publicacion'
df_preparado = preparar_datos_fecha_publicacion(df.copy())

# Ejecutar el proceso 4 veces y calcular los tiempos
execution_times = []
for _ in range(4):
    start_time = time.time()
    df_sorted = ordenar_heap_fecha_publicacion(df_preparado.copy())  # Hacer una copia del DataFrame preparado
    end_time = time.time()
    execution_time = end_time - start_time
    execution_times.append(execution_time)

# Calcular el tiempo promedio
average_time = sum(execution_times) / len(execution_times)

# Imprimir resultados
print("Tiempos de ejecución:", execution_times)
print("Tiempo promedio:", average_time)
# Out:
# Total de caracteres en la columna 'Fecha Publicacion': 30852
# Total de elementos en la columna 'Fecha Publicacion': 7713
# Tiempos de ejecución: [0.0320742130279541, 0.033652305603027344, 0.03824949264526367, 0.034914493560791016]
# Tiempo promedio: 0.03472262620925903

# %% [markdown]
# Autor

# %%
# Función para construir el Heap
def heapify(arr, n, i):
    largest = i  # Inicializar el nodo más grande como la raíz
    left = 2 * i + 1  # Izquierda = 2*i + 1
    right = 2 * i + 2  # Derecha = 2*i + 2

    # Si el hijo izquierdo es mayor que la raíz
    if left < n and arr[left] > arr[largest]:
        largest = left

    # Si el hijo derecho es mayor que el mayor hasta ahora
    if right < n and arr[right] > arr[largest]:
        largest = right

    # Si el mayor no es la raíz
    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i]  # Intercambiar
        heapify(arr, n, largest)  # Recursivamente heapificar el subárbol afectado

# Función para implementar Heap Sort
def heap_sort(arr):
    n = len(arr)

    # Construir el heap (reordenar la matriz)
    for i in range(n // 2 - 1, -1, -1):
        heapify(arr, n, i)

    # Extraer elementos del heap uno por uno
    for i in range(n - 1, 0, -1):
        arr[i], arr[0] = arr[0], arr[i]  # Intercambiar el primer elemento con el último
        heapify(arr, i, 0)  # Heapificar el árbol reducido

# Obtener los Autores válidos
def obtener_autores_validos(df, column_name='Autores'):
    # Asegurarse de que la columna exista y eliminar espacios
    df[column_name] = df[column_name].str.strip()
    # Eliminar valores nulos
    return df[column_name].dropna().tolist()

# Preparar la lista de Autores
autores_validos = obtener_autores_validos(df)

# Variables para medir tiempo de ejecución
tiempos = []
num_ejecuciones = 4

# Realizar 4 ejecuciones y medir el tiempo
for i in range(num_ejecuciones):
    start_time = time.time()  # Inicio del temporizador
    # Ordenar los Autores utilizando Heap Sort
    heap_sort(autores_validos.copy())  # Usar copy() para evitar modificar la lista original
    end_time = time.time()  # Fin del temporizador
    tiempos.append(end_time - start_time)  # Guardar el tiempo de ejecución

# Mostrar resultados
print(f"Total de Autores válidos: {len(autores_validos)}")
print(f"Tiempos de ejecución en {num_ejecuciones} ejecuciones: {tiempos}")
# Out:
# Total de Autores válidos: 7458
# Tiempos de ejecución en 4 ejecuciones: [0.032097816467285156, 0.030103445053100586, 0.02957463264465332, 0.03177070617675781]
