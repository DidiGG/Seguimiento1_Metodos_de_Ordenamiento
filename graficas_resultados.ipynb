# %% [markdown]
# Grafica de resultados Métodos de Ordenamiento para la Columna ISSN

# %%
import matplotlib.pyplot as plt

metodos = ['TimSort', 'CombSort', 'SelectionSort', 'TreeSort', 'PigeonholeSort', 'BucketSort', 
           'QuickSort', 'HeapSort', 'BitonicSort', 'GnomeSort', 'BinaryInsertionSort', 'RadixSort']
tiempos = [0.007689, 0.038260, 2.571225, 2.239390, 3.077102, 0.0169575, 0.0205807, 0.00561475, 
           0.088047, 2.633142, 0.680761, 0.0232490]
variables_ordenadas = [5607, 7713, 7713, 7713, 7713, 5157, 5446, 7458, 5607, 5607, 5607, 5607]

# Ajustar el tamaño de la figura
plt.figure(figsize=(14, 11))  

# Crear la gráfica de barras
bars = plt.bar(metodos, tiempos, color='blue')

# Agregar los valores encima de las barras (tiempo y variables ordenadas)
for bar, tiempo, variables in zip(bars, tiempos, variables_ordenadas):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.05, 
             f'{tiempo:.6f} seg \n{variables} size', ha='center', fontsize=9)

# Agregar título y etiquetas
plt.title('Tiempos y Cantidad de Variables Ordenadas por Método (ISSN)')
plt.xlabel('Métodos de Ordenamiento')
plt.ylabel('Tiempo de Ejecución (segundos)')

# Rotar los nombres de los métodos para mejor legibilidad
plt.xticks(rotation=45, ha='right')

# Ajustar los márgenes
plt.tight_layout()

# Mostrar la gráfica
plt.show()

# %% [markdown]
# Grafica de resultados Métodos de Ordenamiento para la Columna Fecha Puclicación

# %%
import matplotlib.pyplot as plt

metodos = ['TimSort', 'CombSort', 'SelectionSort', 'TreeSort', 'PigeonholeSort', 'BucketSort', 
           'QuickSort', 'HeapSort', 'BitonicSort', 'GnomeSort', 'BinaryInsertionSort', 'RadixSort']
tiempos = [
    0.008573,
    0.024765,
    2.489704,
    1.728102,
    0.00403175,
    1.222325,
    0.005409,
    0.034722,
    0.069967,
    6.624545,
    0.422481,
    0.0192494
]
variables_ordenadas = [
    7713,
    7713,
    7713,
    7713,
    6295,
    7713,
    7713,
    7713,
    7713,
    7713,
    7713,
    7713
]

# Ajustar el tamaño de la figura
plt.figure(figsize=(14, 11))  

# Crear la gráfica de barras
bars = plt.bar(metodos, tiempos, color='blue')

# Agregar los valores encima de las barras (tiempo y variables ordenadas)
for bar, tiempo, variables in zip(bars, tiempos, variables_ordenadas):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.05, 
             f'{tiempo:.6f} seg \n{variables} size', ha='center', fontsize=9)

# Agregar título y etiquetas
plt.title('Tiempos y Cantidad de Variables Ordenadas por Método (Fecha Publicacion)')
plt.xlabel('Métodos de Ordenamiento')
plt.ylabel('Tiempo de Ejecución (segundos)')

# Rotar los nombres de los métodos para mejor legibilidad
plt.xticks(rotation=45, ha='right')

# Ajustar los márgenes
plt.tight_layout()

# Mostrar la gráfica
plt.show()

# %% [markdown]
# Grafica de resultados Métodos de Ordenamiento para la Columna Autores

# %%
import matplotlib.pyplot as plt

metodos = [
    "TimSort",
    "CombSort",
    "SelectionSort",
    "TreeSort",
    "PigeonholeSort",
    "BucketSort",
    "QuickSort",
    "HeapSort",
    "BitonicSort",
    "GnomeSort",
    "BinaryInsertionSort",
    "RadixSort",
]
tiempos = [
    0.008385,
    0.052788,
    2.895881,
    2.006890,
    0.0040905,
    0.00226,
    0.01649125,
    0.0308864,
    0.083716,
    4.77543008,
    0.5828728,
    1.627794,
]
variables_ordenadas = [
    7713,
    7713,
    7713,
    7713,
    7713,
    7458,
    7458,
    7458,
    7458,
    7458,
    7458,
    7713,
]

# Ajustar el tamaño de la figura
plt.figure(figsize=(14, 11))

# Crear la gráfica de barras
bars = plt.bar(metodos, tiempos, color="blue")

# Agregar los valores encima de las barras (tiempo y variables ordenadas)
for bar, tiempo, variables in zip(bars, tiempos, variables_ordenadas):
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() + 0.05,
        f"{tiempo:.6f} seg \n{variables} size",
        ha="center",
        fontsize=9,
    )

# Agregar título y etiquetas
plt.title("Tiempos y Cantidad de Variables Ordenadas por Método (Autores)")
plt.xlabel("Métodos de Ordenamiento")
plt.ylabel("Tiempo de Ejecución (segundos)")

# Rotar los nombres de los métodos para mejor legibilidad
plt.xticks(rotation=45, ha="right")

# Ajustar los márgenes
plt.tight_layout()

# Mostrar la gráfica
plt.show()
